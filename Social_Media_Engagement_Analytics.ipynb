# %% [markdown]
# <a href="https://colab.research.google.com/github/saranyaece30111998-analyst/SOCIAL-MEDIA-ENGAGEMENT-ANALYTICS/blob/main/Social_Media_Engagement_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module End  Assignment: Python For Data Analysis
# # “Social Media Engagement Analytics”

# %% [markdown]
# # ❖Task 1 — Data Import & Setup

# %%
import pandas as pd

# import data from github
url = "https://raw.githubusercontent.com/GeethaGunasekaran1/Dataset_rep/main/social_media_engagement_5000.csv"

# Load dataset
df = pd.read_csv(url)

# %%
# checking data set
df
# Out:
#       user_id   age  gender    country  post_id post_type post_category  \
# 0       25795  43.0  Female     Brazil   496713     image       fitness
# 1       10860  33.0    Male     Brazil   157326      reel          food
# 2       86820  32.0  Female         UK   109864      text          food
# 3       64886  51.0   Other     France   848877      text       fitness
# 4       16265  34.0   Other         UK   449706     image       fitness
# ...       ...   ...     ...        ...      ...       ...           ...
# 4995    59500  44.0    Male  Australia   441541     video     education
# 4996    22100  38.0   Other        UAE   677076      reel     education
# 4997    67021  63.0  Female        USA   273595      text        travel
# 4998    29800  13.0  Female    Germany   785644     video       fitness
# 4999    73400  54.0   Other      Japan   712252      text        travel
#
#         likes  comments  shares  watch_time_sec  impression_count   posted_at  \
# ...

# %%
# taking copy for the data
df_safe = df.copy()

# %% [markdown]
# # ❖Checking /converting data typesdata types

# %%
# checking data types
print(df.dtypes)
# Out:
# user_id               int64
# age                 float64
# gender               object
# country              object
# post_id               int64
# post_type            object
# post_category        object
# likes               float64
# comments            float64
# shares              float64
# watch_time_sec        int64
# impression_count      int64
# posted_at            object
# follower_count        int64
# is_verified            bool
# device_type          object
# sentiment            object
# hashtags             object
# engagement_rate     float64
# dtype: object

# %%
# changeing data types
# changeing user id into object
df['user_id'] = df['user_id'].astype('object')

# changeing user id into object
df['post_id'] = df['post_id'].astype('object')

# changing data types of posted at into date

df['posted_at'] = pd.to_datetime(df['posted_at'],format="mixed",errors='coerce',dayfirst=True)

# %% [markdown]
# # ❖ Task 2 — Data Cleaning

# %%
# checkinf for duplicated value
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking for null values
df.isnull().sum()
# Out:
# user_id               0
# age                 150
# gender              150
# country               0
# post_id               0
# post_type             0
# post_category         0
# likes               150
# comments            150
# shares              150
# watch_time_sec        0
# impression_count      0
# posted_at             0
# follower_count        0
# is_verified           0
# device_type           0
# sentiment           150
# hashtags              0
# engagement_rate       0
# dtype: int64

# %% [markdown]
# # age coloumn

# %%
# find describtion of age
df["age"].describe()
# Out:
# count    4850.000000
# mean       38.454021
# std        14.912381
# min        13.000000
# 25%        26.000000
# 50%        38.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
# imputed age values
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# /tmp/ipykernel_1044/939189976.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
# changeing data types of age
df['age'] = df['age'].astype('int')

# %% [markdown]
# # GENDER COLOUMN

# %%
#FIND UNIQUES VALUES
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
#FIND VALUES COUNT
df['gender'].value_counts()
# Out:
# gender
# Male      1849
# Other     1581
# Female    1570
# Name: count, dtype: int64

# %%
df["gender"] = df['gender'].fillna("Male")

# %%
#POST TYPES COLUMN
df['post_type'] = df['post_type'].str.title().str.strip()

# %%
#POST CATEGORY COLUMN
df['post_category'] = df['post_category'].str.title().str.strip()

# %% [markdown]
# # LIKES COLUMN

# %%
#imputing likes value
df['likes'] = df['likes'].fillna(df['likes'].median())

# %%
# changeing data types
df['likes'] = df['likes'].astype('int')

# %% [markdown]
# # COMMENTS COLOUMN

# %%
#IMPUTING COLUMN
df['comments'].fillna(df['comments'].median(), inplace=True)
# Out:
# /tmp/ipykernel_1044/450589731.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['comments'].fillna(df['comments'].median(), inplace=True)

# %%
# changeing data types
df['comments'] = df['comments'].astype('int')

# %% [markdown]
# # SHARES COLUMN

# %%
#IMPUTING COLUMN
df['shares'].fillna(df['shares'].median(), inplace=True)
# Out:
# /tmp/ipykernel_1044/1316992147.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['shares'].fillna(df['shares'].median(), inplace=True)

# %%
# changeing data types
df['shares'] = df['shares'].astype('int')

# %%
#device column
df['device_type'] = df['device_type'].str.title().str.strip()

# %% [markdown]
# #sentiment column

# %%
#FIND UNIQUES VALUES
df['sentiment'].unique()
# Out:
# array(['Negative', 'Positive', 'Neutral'], dtype=object)

# %%
#finding values count
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    2513
# Neutral     1527
# Negative     960
# Name: count, dtype: int64

# %%
#imputing value
df["sentiment"] = df['sentiment'].fillna("positive")

# %%
#formating the column
df['sentiment'] = df['sentiment'].str.capitalize().str.strip()

# %%
#counting hashtags

df['hashtag_count'] = df['hashtags'].str.count(r'#\w+')

# %% [markdown]
# # cleaned data

# %%
df
# Out:
#      user_id  age  gender    country post_id post_type post_category  likes  \
# 0      25795   43  Female     Brazil  496713     Image       Fitness   7011
# 1      10860   33    Male     Brazil  157326      Reel          Food  11750
# 2      86820   32  Female         UK  109864      Text          Food   4862
# 3      64886   51   Other     France  848877      Text       Fitness   5350
# 4      16265   34   Other         UK  449706     Image       Fitness  12682
# ...      ...  ...     ...        ...     ...       ...           ...    ...
# 4995   59500   44    Male  Australia  441541     Video     Education  16210
# 4996   22100   38   Other        UAE  677076      Reel     Education  16924
# 4997   67021   63  Female        USA  273595      Text        Travel  13487
# 4998   29800   13  Female    Germany  785644     Video       Fitness  16894
# 4999   73400   54   Other      Japan  712252      Text        Travel  14830
#
# ...

# %%
#checking data types
print(df.dtypes)
# Out:
# user_id                     object
# age                          int64
# gender                      object
# country                     object
# post_id                     object
# post_type                   object
# post_category               object
# likes                        int64
# comments                     int64
# shares                       int64
# watch_time_sec               int64
# impression_count             int64
# posted_at           datetime64[ns]
# follower_count               int64
# is_verified                   bool
# device_type                 object
# sentiment                   object
# hashtags                    object
# engagement_rate            float64
# hashtag_count                int64
# dtype: object

# %%
#checking for nulls
df.isnull().sum()
# Out:
# user_id             0
# age                 0
# gender              0
# country             0
# post_id             0
# post_type           0
# post_category       0
# likes               0
# comments            0
# shares              0
# watch_time_sec      0
# impression_count    0
# posted_at           0
# follower_count      0
# is_verified         0
# device_type         0
# sentiment           0
# hashtags            0
# engagement_rate     0
# hashtag_count       0
# dtype: int64

# %% [markdown]
# # ❖ Task 3 — Data Exploration using Pandas

# %%
# 1. View dataset structure
#showing first five rows
df.head()
# Out:
#   user_id  age  gender country post_id post_type post_category  likes  \
# 0   25795   43  Female  Brazil  496713     Image       Fitness   7011
# 1   10860   33    Male  Brazil  157326      Reel          Food  11750
# 2   86820   32  Female      UK  109864      Text          Food   4862
# 3   64886   51   Other  France  848877      Text       Fitness   5350
# 4   16265   34   Other      UK  449706     Image       Fitness  12682
#
#    comments  shares  watch_time_sec  impression_count  posted_at  \
# 0       354    1157            5726             44650 2022-12-17
# 1      2606    1807            5947             80216 2023-06-02
# 2       344     955            6946             44858 2023-05-07
# 3      1083    1049             229             70455 2023-02-12
# 4      2735    1300            4798              6019 2023-05-23
#
#    follower_count  is_verified device_type sentiment               hashtags  \
# ...

# %%
#showing last five rows
df.tail()
# Out:
#      user_id  age  gender    country post_id post_type post_category  likes  \
# 4995   59500   44    Male  Australia  441541     Video     Education  16210
# 4996   22100   38   Other        UAE  677076      Reel     Education  16924
# 4997   67021   63  Female        USA  273595      Text        Travel  13487
# 4998   29800   13  Female    Germany  785644     Video       Fitness  16894
# 4999   73400   54   Other      Japan  712252      Text        Travel  14830
#
#       comments  shares  watch_time_sec  impression_count  posted_at  \
# 4995      2013    1837            6190             42977 2022-06-25
# 4996      2734    1583            7764             34196 2022-11-18
# 4997      1497     167            7466             23680 2023-04-06
# 4998      1289    1713            4991             89013 2022-05-16
# 4999       503    1798            3743             14234 2023-03-04
#
#       follower_count  is_verified device_type sentiment  \
# ...

# %%
#showing shape
print(df.shape)
# Out:
# (5000, 20)

# %%
#column name
df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'country', 'post_id', 'post_type',
#        'post_category', 'likes', 'comments', 'shares', 'watch_time_sec',
#        'impression_count', 'posted_at', 'follower_count', 'is_verified',
#        'device_type', 'sentiment', 'hashtags', 'engagement_rate',
#        'hashtag_count'],
#       dtype='object')

# %%
#Check data types and info with info() and dtypes.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           5000 non-null   object
#  1   age               5000 non-null   int64
#  2   gender            5000 non-null   object
#  3   country           5000 non-null   object
#  4   post_id           5000 non-null   object
#  5   post_type         5000 non-null   object
#  6   post_category     5000 non-null   object
#  7   likes             5000 non-null   int64
#  8   comments          5000 non-null   int64
#  9   shares            5000 non-null   int64
#  10  watch_time_sec    5000 non-null   int64
#  11  impression_count  5000 non-null   int64
#  12  posted_at         5000 non-null   datetime64[ns]
#  13  follower_count    5000 non-null   int64
#  14  is_verified       5000 non-null   bool
#  15  device_type       5000 non-null   object
# ...

# %%
#checking data types
print(df.dtypes)
# Out:
# user_id                     object
# age                          int64
# gender                      object
# country                     object
# post_id                     object
# post_type                   object
# post_category               object
# likes                        int64
# comments                     int64
# shares                       int64
# watch_time_sec               int64
# impression_count             int64
# posted_at           datetime64[ns]
# follower_count               int64
# is_verified                   bool
# device_type                 object
# sentiment                   object
# hashtags                    object
# engagement_rate            float64
# hashtag_count                int64
# dtype: object

# %%
#Generate summary statistics using describe().
# Select only integer columns
int_cols = df.select_dtypes(include=['int64'])

# Generate summary statistics
print(int_cols.describe())
# Out:
#                age         likes     comments     shares  watch_time_sec  \
# count  5000.000000   5000.000000  5000.000000  5000.0000     5000.000000
# mean     38.440400  10106.982400  1502.039800  1002.9106     4014.503200
# std      14.687151   5702.293022   856.393312   570.8552     2308.096459
# min      13.000000     10.000000     0.000000     0.0000        0.000000
# 25%      26.000000   5235.000000   792.000000   511.0000     2017.750000
# 50%      38.000000  10105.000000  1497.000000  1012.0000     4034.500000
# 75%      51.000000  14959.000000  2235.250000  1483.0000     6020.250000
# max      64.000000  19998.000000  2999.000000  1999.0000     7998.000000
#
#        impression_count  follower_count  hashtag_count
# count       5000.000000     5000.000000    5000.000000
# mean       50013.732800   393698.224800       1.998600
# std        28844.939104   230927.884535       0.812853
# min          105.000000       87.000000       1.000000
# ...

# %%
# 4. Categorical distributions
print(df['post_type'].value_counts())
# Out:
# post_type
# Reel     1283
# Image    1247
# Text     1245
# Video    1225
# Name: count, dtype: int64
# 10
# ['Negative' 'Positive' 'Neutral']

# %%
print(df['country'].nunique())
# Out:
# 10

# %%
print(df['sentiment'].unique())
# Out:
# ['Negative' 'Positive' 'Neutral']

# %%
# Correlation matrix for numeric fields
corr_matrix = df.corr(numeric_only=True)
print(corr_matrix)
# Out:
#                        age     likes  comments    shares  watch_time_sec  \
# age               1.000000 -0.036323 -0.007284  0.013871        0.005542
# likes            -0.036323  1.000000 -0.018421  0.004712        0.008710
# comments         -0.007284 -0.018421  1.000000  0.006142       -0.016351
# shares            0.013871  0.004712  0.006142  1.000000        0.014658
# watch_time_sec    0.005542  0.008710 -0.016351  0.014658        1.000000
# impression_count  0.013322  0.007952 -0.009395 -0.005204       -0.004335
# follower_count   -0.024894 -0.022982 -0.011733 -0.010783        0.002761
# is_verified      -0.000079 -0.016199 -0.012398  0.007025        0.012326
# engagement_rate   0.008039  0.093521  0.000051  0.021724       -0.001148
# hashtag_count     0.007173 -0.002190 -0.015230  0.013379       -0.023301
#
#                   impression_count  follower_count  is_verified  \
# age                       0.013322       -0.024894    -0.000079
# ...

# %%
 #6. Groupby summaries
print(df.groupby('post_type')['likes'].mean())
# Out:
# post_type
# Image    10104.852446
# Reel     10037.784879
# Text     10100.132530
# Video    10188.586122
# Name: likes, dtype: float64

# %%
print(df.groupby('country')['impression_count'].mean())
# Out:
# country
# Australia    48346.383367
# Brazil       49193.174603
# Canada       48703.150097
# France       51727.673387
# Germany      48605.406122
# India        52462.386916
# Japan        49616.135593
# UAE          48928.413519
# UK           51119.393509
# USA          51263.872255
# Name: impression_count, dtype: float64

# %%
# 1. Create new fields
df['engagement_score'] = df['likes'] + df['comments'] + df['shares']

# %%
import numpy as np
df['log_likes'] = np.log1p(df['likes'])

# %%
# 2. Groupby summaries
print(df.groupby('post_type')['engagement_score'].mean())
# Out:
# post_type
# Image    12649.377706
# Reel     12524.014030
# Text     12613.228112
# Video    12664.580408
# Name: engagement_score, dtype: float64

# %%
print(df.groupby('country')['engagement_score'].mean())
# Out:
# country
# Australia    12809.604462
# Brazil       12385.972222
# Canada       12605.883041
# France       12903.370968
# Germany      12635.640816
# India        12492.678505
# Japan        12578.637712
# UAE          12757.763419
# UK           12384.361055
# USA          12575.449102
# Name: engagement_score, dtype: float64

# %%
print(df.groupby('sentiment')['engagement_score'].mean())
# Out:
# sentiment
# Negative    12731.483333
# Neutral     12448.149312
# Positive    12665.784322
# Name: engagement_score, dtype: float64

# %% [markdown]
# # Task 5 — Statistical Analysis

# %%
# Select relevant columns
cols = ['likes', 'comments', 'shares', 'watch_time_sec', 'engagement_rate', 'follower_count']

data = df[cols]

# Mean, Median, Mode
print("Mean:\n", data.mean())
print("\nMedian:\n", data.median())
print("\nMode:\n", data.mode().iloc[0])

# Standard Deviation & Variance
print("\nStandard Deviation:\n", data.std())
print("\nVariance:\n", data.var())

# Percentiles (25th, 50th, 75th)
print("\n25th Percentile:\n", data.quantile(0.25))
print("\n50th Percentile:\n", data.quantile(0.50))  # same as median
print("\n75th Percentile:\n", data.quantile(0.75))

# (Skewness & Kurtosis
print("\nSkewness:\n", data.skew())
print("\nKurtosis:\n", data.kurt())
# Out:
# Mean:
#  likes               10106.982400
# comments             1502.039800
# shares               1002.910600
# watch_time_sec       4014.503200
# engagement_rate         0.964356
# follower_count     393698.224800
# dtype: float64
#
# Median:
#  likes               10105.000000
# comments             1497.000000
# shares               1012.000000
# watch_time_sec       4034.500000
# engagement_rate         0.253896
# follower_count     388982.000000
# dtype: float64
#
# Mode:
#  likes               10105.000000
# comments             1497.000000
# shares               1012.000000
# watch_time_sec        916.000000
# engagement_rate         0.006363
# follower_count     497502.000000
# Name: 0, dtype: float64
#
# Standard Deviation:
#  likes                5702.293022
# comments              856.393312
# shares                570.855200
# watch_time_sec       2308.096459
# engagement_rate         5.318029
# follower_count     230927.884535
# dtype: float64
#
# Variance:
# ...

# %% [markdown]
# # final data set

# %%
df
# Out:
#      user_id  age  gender    country post_id post_type post_category  likes  \
# 0      25795   43  Female     Brazil  496713     Image       Fitness   7011
# 1      10860   33    Male     Brazil  157326      Reel          Food  11750
# 2      86820   32  Female         UK  109864      Text          Food   4862
# 3      64886   51   Other     France  848877      Text       Fitness   5350
# 4      16265   34   Other         UK  449706     Image       Fitness  12682
# ...      ...  ...     ...        ...     ...       ...           ...    ...
# 4995   59500   44    Male  Australia  441541     Video     Education  16210
# 4996   22100   38   Other        UAE  677076      Reel     Education  16924
# 4997   67021   63  Female        USA  273595      Text        Travel  13487
# 4998   29800   13  Female    Germany  785644     Video       Fitness  16894
# 4999   73400   54   Other      Japan  712252      Text        Travel  14830
#
# ...

# %% [markdown]
# # ❖ Task 6 — Data Visualization
# # ● Matplotlib

# %%
import matplotlib.pyplot as plt

# Scatter: likes vs impressions
plt.scatter(df['impression_count'], df['likes'], alpha=0.6, color='blue')
plt.xlabel('Impressions')
plt.ylabel('Likes')
plt.title('Likes vs Impressions')
plt.show()

# %% [markdown]
# # Interpretation

# %%
# Line: daily engagement trend
plt.plot(df['posted_at'], df['engagement_rate'], marker='o', linestyle='-')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Engagement Rate')
plt.title('Daily Engagement Trend')
plt.show()

# %%
# Bar: posts by category
df['post_category'].value_counts().plot(kind='bar', color='green')
plt.title('Posts by Category')
plt.show()

# %%
# Pie: gender distribution
df['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
# Histogram: age
plt.hist(df['age'], bins=15, color='purple', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
# Box: engagement rate
plt.boxplot(df['engagement_rate'])
plt.title('Engagement Rate Distribution')
plt.show()

# %% [markdown]
# # seaborn visuals

# %%
import seaborn as sns
import numpy as np

# Count plot: post type
sns.countplot(x='post_type', data=df)
plt.title('Post Type Count')
plt.show()

# %%
# Bar plot: avg likes by category
sns.barplot(x='post_category', y='likes', data=df, estimator=np.mean)
plt.title('Average Likes by Category')
plt.show()

# %%
# Violin: followers vs sentiment
sns.violinplot(x='sentiment', y='follower_count', data=df)
plt.title('Followers vs Sentiment')
plt.show()

# %%
# Pair plot: numeric features
sns.pairplot(df[['likes','comments','shares','impression_count','engagement_rate']])
plt.show()

# %%
# Heatmap: correlation matrix
corr = df[['likes','comments','shares','impression_count','engagement_rate']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Swarm plot: engagement vs device
sns.stripplot(x='device_type', y='engagement_rate', data=df, jitter=True)

plt.title('Engagement Rate vs Device Type')
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# --- Line Chart: Engagement Trend ---

line_fig = px.line(df, x='posted_at', y='engagement_rate',
                   title='Engagement Trend', markers=True)
line_fig.update_xaxes(rangeslider_visible=True)

# --- Bar Chart: Avg Likes by Category ---
bar_data = df.groupby('post_category')['likes'].mean().reset_index().sort_values('likes', ascending=False)
bar_fig = px.bar(bar_data, x='post_category', y='likes',
                 title='Avg Likes by Category')
bar_fig.update_traces(marker_color='teal')

# --- Scatter/Bubble Chart: Likes vs Impressions ---
scatter_fig = px.scatter(df, x='impression_count', y='likes',
                         size='follower_count', color='post_category',
                         hover_name='post_type',
                         title='Likes vs Impressions Bubble Chart',
                         trendline='ols')
scatter_fig.update_xaxes(type='log')

# --- Combine into Subplots ---
fig = make_subplots(rows=3, cols=1,
                    subplot_titles=("Engagement Trend",
                                    "Avg Likes by Category",
                                    "Likes vs Impressions Bubble Chart"),
                    vertical_spacing=0.15)

# Add traces from each fig
for trace in line_fig.data:
    fig.add_trace(trace, row=1, col=1)

for trace in bar_fig.data:
    fig.add_trace(trace, row=2, col=1)

for trace in scatter_fig.data:
    fig.add_trace(trace, row=3, col=1)

# Update layout
fig.update_layout(height=1200, width=900,
                  title_text="Interactive Engagement Dashboard",
                  showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Save df as CSV
df.to_csv('dataset.csv', index=False)

# Download the file to your local machine
from google.colab import files
files.download('dataset.csv')
